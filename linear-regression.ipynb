# %%
# imports

import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read data
df = pd.read_csv('challenge_dataset.txt', names=['X','Y'])

# %%
#split data
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = np.array(train_test_split(df['X'], df['Y'], test_size=0.1), copy=False)

# %%
#visualize  training data
plt.scatter(X_train.values.reshape(-1, 1), Y_train.values.reshape(-1, 1))
plt.show()

# %%
#Train model
reg = linear_model.LinearRegression()
reg.fit(X_train.values.reshape(-1, 1), Y_train.values.reshape(-1, 1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Print Accuracy
print reg.score(X_test.values.reshape(-1, 1), Y_test.values.reshape(-1, 1))
# Out:
# 0.47686087692

# %%
#visualize testing and training data(testing with orange dots and training with blue dots)
plt.scatter(X_train.values.reshape(-1, 1), Y_train.values.reshape(-1, 1))
plt.scatter(X_test.values.reshape(-1, 1), Y_test.values.reshape(-1, 1))
plt.plot(X_test.values.reshape(-1, 1), reg.predict(X_test.values.reshape(-1, 1)))
plt.show()

# %%
#visualize testing data
plt.scatter(X_test.values.reshape(-1, 1), Y_test.values.reshape(-1, 1),c='Y')
plt.plot(X_test.values.reshape(-1, 1), reg.predict(X_test.values.reshape(-1, 1)))
plt.show()
